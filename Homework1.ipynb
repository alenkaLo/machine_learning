# %%
# Copyright Loseava 2025

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import seaborn as sns
#from sklearn.preprocessing import StandardScaler

# Загрузка данных
flights_data = pd.read_csv('Combined_Flights_2019.csv')

# %%
#N (число объектов)
#d (число признаков)
N, d = flights_data.shape
N, d
# Out:
# (8091684, 61)

# %%
flights_data.head()
# Out:
#    FlightDate    Airline Origin Dest  Cancelled  Diverted  CRSDepTime  \
# 0  2019-04-01  Envoy Air    LIT  ORD      False     False        1212
# 1  2019-04-02  Envoy Air    LIT  ORD      False     False        1212
# 2  2019-04-03  Envoy Air    LIT  ORD      False     False        1212
# 3  2019-04-04  Envoy Air    LIT  ORD      False     False        1212
# 4  2019-04-05  Envoy Air    LIT  ORD      False     False        1212
#
#    DepTime  DepDelayMinutes  DepDelay  ...  WheelsOff  WheelsOn  TaxiIn  \
# 0   1209.0              0.0      -3.0  ...     1219.0    1342.0     8.0
# 1   1200.0              0.0     -12.0  ...     1210.0    1339.0     9.0
# 2   1203.0              0.0      -9.0  ...     1214.0    1336.0     6.0
# 3   1435.0            143.0     143.0  ...     1452.0    1615.0     6.0
# 4   1216.0              4.0       4.0  ...     1234.0    1357.0    13.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# ...

# %%
#Наличие пропущенных значений в процентах
flights_data.isnull().sum().sum()/(N*d)*100
# Out:
# 0.0052476543394104

# %%
#Несбалансированные классы (указать соотношение, например, 5/95)
#посмотрим на количество строк с разными классами: 
flights_data['Cancelled'].value_counts()
# Out:
# Cancelled
# False    7938055
# True      153629
# Name: count, dtype: int64

# %%
# отношение количества строк с false к true 
# датасет очень несбалансирован в сторону False (в ~51 раз)
len(flights_data.loc[flights_data['Cancelled']==False])//len(flights_data.loc[flights_data['Cancelled']==True])
# Out:
# 51
